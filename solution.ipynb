# %%
class Point:
    def show(x, y):
        return x+y

a = Point(1,2)
a.show()

b = Point(3,4)
b.show()

a = a+b
a.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-88350e88da2e> in <module>
#       3         return x+y
#       4
# ----> 5 a = Point(1,2)
#       6 a.show()
#       7
#
# TypeError: Point() takes no arguments

# %%
import csv

file = open("./seoul.csv", "r", encoding = "cp949")
data = csv.reader(file)

next(data)
initData = next(data)
highest = float(initData[4])
lowest = float(initData[3])
dailyTempRange = highest - lowest
highestDate = initData[0]
lowestDate = initData[0]
biggestRange = initData[0]

dlfryck = [dailyTempRange]
maxa = 0
maxb = 0
maxaa = 0

for row in data:
    tempRange = float(row[4])-float(row[3])
    # print(tempRange)
    dailyTempRange = tempRange
    biggestRange = row[0]
    dlfryck.append(dailyTempRange)
    
for i in range(25):
    maxb = 0
    for i in range(7):
        maxb += dlfryck[j]
    if maxa < maxb:
        maxa = maxb
        maxaa = i
        
file.close()

print("Max week = 5 /", maxaa, "~ 5 /", maxaa+6)
# Out:
# Max week = 5 / 6 ~ 5 / 12
